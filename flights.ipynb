# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('flights')

#df = pd.DataFrame(df)
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df.year.unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960])

# %%
df.isna().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %% [markdown]
# fetch the records  where year >=1950

# %%
df[df['year'] >= 1950][['month', 'passengers']].head(5)
# Out:
#    month  passengers
# 12   Jan         115
# 13   Feb         126
# 14   Mar         141
# 15   Apr         135
# 16   May         125

# %% [markdown]
# total no of passengers

# %%
#df.passengers.sum()
sum(df.passengers)
# Out:
# 40363

# %% [markdown]
# fetch years where passengers greater than 400

# %%
df[df['passengers'] > 400]['year'].unique()
# Out:
# array([1956, 1957, 1958, 1959, 1960])

# %% [markdown]
# calculate avergae passengers for all years

# %%
round(df.passengers.mean())
# Out:
# 280

# %% [markdown]
# find the record of jan month of year 1950

# %%
df.query('year== 1950 & month == "Jan"')
# Out:
#     year month  passengers
# 12  1950   Jan         115

# %% [markdown]
# draw the bar chat year vs passengers

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['year'].astype(str), df['passengers'], color='skyblue')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.title('Total Passengers per Year')
# Out:
# Text(0.5, 1.0, 'Total Passengers per Year')

# %% [markdown]
# draw the bar chat for all months in a particular year

# %%
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightblue',
          'lightyellow', 'lightcyan', 'lavender', 'lightpink', 'lightgray',
          'lightgoldenrodyellow', 'whitesmoke']
specific_year = 1995
plt.figure(figsize=(10, 6))
plt.bar(df['month'], df['passengers'], color=colors)
plt.xlabel('Month')
plt.ylabel('Number of Passengers')
plt.title(f'Passengers per Month in {specific_year}')
# Out:
# Text(0.5, 1.0, 'Passengers per Month in 1995')

# %% [markdown]
# draw the pie flot year vs passengers

# %%
k = df.head(20)
labels = k['year'].astype(str)
sizes = k['passengers']
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Passenger Distribution by Year')
plt.axis('equal')
plt.legend()
plt.show()

# %% [markdown]
# draw scatter plot

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['year'], df['passengers'], color='coral', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.title('Scatter Plot of Passengers vs. Year')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Passengers vs. Year')
